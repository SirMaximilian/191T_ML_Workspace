# %% [markdown]
# # Gilbert Barr
#
# Assignment 2

# %%
import math
# %matplotlib inline
import matplotlib.pyplot as plt

F = lambda W, X: sum([w*x for w,x in zip(W,X)])
sigmoid = lambda y: 1/(1+math.exp(-y))
classify = lambda y: 1 if y>0.5 else 0
#data 2
#data = [((1, 0, 0), 0), ((1, 1, 7), 0), ((1, -3, -2), 0), ((1, 8, 9), 1), ((1, 4, 3), 1), ((1, 5, -2), 1), ((1, 0, 0), 0), ((1, 6, 9), 1), ((1, 4, 2), 1), ((1, 1, -9), 1), ((1, -7, 7), 0), ((1, 0, -1), 1), ((1, 9, -4), 1), ((1, 1, 0), 1), ((1, -2, -5), 1), ((1, 2, 3), 1), ((1, -7, 2), 0), ((1, -3, 0), 0), ((1, 5, 0), 1), ((1, 0, -3), 1), ((1, -2, 3), 0), ((1, 9, 6), 1), ((1, 0, -8), 1), ((1, 0, 2), 1), ((1, -8, 6), 0), ((1, 1, 9), 0), ((1, 0, 5), 0), ((1, -4, 9), 0), ((1, 8, 2), 1), ((1, 2, 6), 0)]
#data 4
data = [((1, 5.1, 3.5), 0), ((1, 4.9, 3.0), 0), ((1, 4.7, 3.2), 0), ((1, 4.6, 3.1), 0), ((1, 5.0, 3.6), 0), ((1, 5.4, 3.9), 0), ((1, 4.6, 3.4), 0), ((1, 5.0, 3.4), 0), ((1, 4.4, 2.9), 0), ((1, 4.9, 3.1), 0), ((1, 5.4, 3.7), 0), ((1, 4.8, 3.4), 0), ((1, 4.8, 3.0), 0), ((1, 4.3, 3.0), 0), ((1, 5.8, 4.0), 0), ((1, 5.7, 4.4), 0), ((1, 5.4, 3.9), 0), ((1, 5.1, 3.5), 0), ((1, 5.7, 3.8), 0), ((1, 5.1, 3.8), 0), ((1, 5.4, 3.4), 0), ((1, 5.1, 3.7), 0), ((1, 4.6, 3.6), 0), ((1, 5.1, 3.3), 0), ((1, 4.8, 3.4), 0), ((1, 5.0, 3.0), 0), ((1, 5.0, 3.4), 0), ((1, 5.2, 3.5), 0), ((1, 5.2, 3.4), 0), ((1, 4.7, 3.2), 0), ((1, 4.8, 3.1), 0), ((1, 5.4, 3.4), 0), ((1, 5.2, 4.1), 0), ((1, 5.5, 4.2), 0), ((1, 4.9, 3.1), 0), ((1, 5.0, 3.2), 0), ((1, 5.5, 3.5), 0), ((1, 4.9, 3.6), 0), ((1, 4.4, 3.0), 0), ((1, 5.1, 3.4), 0), ((1, 5.0, 3.5), 0), ((1, 4.5, 2.3), 0), ((1, 4.4, 3.2), 0), ((1, 5.0, 3.5), 0), ((1, 5.1, 3.8), 0), ((1, 4.8, 3.0), 0), ((1, 5.1, 3.8), 0), ((1, 4.6, 3.2), 0), ((1, 5.3, 3.7), 0), ((1, 5.0, 3.3), 0), ((1, 7.0, 3.2), 1), ((1, 6.4, 3.2), 1), ((1, 6.9, 3.1), 1), ((1, 5.5, 2.3), 1), ((1, 6.5, 2.8), 1), ((1, 5.7, 2.8), 1), ((1, 6.3, 3.3), 1), ((1, 4.9, 2.4), 1), ((1, 6.6, 2.9), 1), ((1, 5.2, 2.7), 1), ((1, 5.0, 2.0), 1), ((1, 5.9, 3.0), 1), ((1, 6.0, 2.2), 1), ((1, 6.1, 2.9), 1), ((1, 5.6, 2.9), 1), ((1, 6.7, 3.1), 1), ((1, 5.6, 3.0), 1), ((1, 5.8, 2.7), 1), ((1, 6.2, 2.2), 1), ((1, 5.6, 2.5), 1), ((1, 5.9, 3.2), 1), ((1, 6.1, 2.8), 1), ((1, 6.3, 2.5), 1), ((1, 6.1, 2.8), 1), ((1, 6.4, 2.9), 1), ((1, 6.6, 3.0), 1), ((1, 6.8, 2.8), 1), ((1, 6.7, 3.0), 1), ((1, 6.0, 2.9), 1), ((1, 5.7, 2.6), 1), ((1, 5.5, 2.4), 1), ((1, 5.5, 2.4), 1), ((1, 5.8, 2.7), 1), ((1, 6.0, 2.7), 1), ((1, 5.4, 3.0), 1), ((1, 6.0, 3.4), 1), ((1, 6.7, 3.1), 1), ((1, 6.3, 2.3), 1), ((1, 5.6, 3.0), 1), ((1, 5.5, 2.5), 1), ((1, 5.5, 2.6), 1), ((1, 6.1, 3.0), 1), ((1, 5.8, 2.6), 1), ((1, 5.0, 2.3), 1), ((1, 5.6, 2.7), 1), ((1, 5.7, 3.0), 1), ((1, 5.7, 2.9), 1), ((1, 6.2, 2.9), 1), ((1, 5.1, 2.5), 1), ((1, 5.7, 2.8), 1), ((1, 6.3, 3.3), 2), ((1, 5.8, 2.7), 2), ((1, 7.1, 3.0), 2), ((1, 6.3, 2.9), 2), ((1, 6.5, 3.0), 2), ((1, 7.6, 3.0), 2), ((1, 4.9, 2.5), 2), ((1, 7.3, 2.9), 2), ((1, 6.7, 2.5), 2), ((1, 7.2, 3.6), 2), ((1, 6.5, 3.2), 2), ((1, 6.4, 2.7), 2), ((1, 6.8, 3.0), 2), ((1, 5.7, 2.5), 2), ((1, 5.8, 2.8), 2), ((1, 6.4, 3.2), 2), ((1, 6.5, 3.0), 2), ((1, 7.7, 3.8), 2), ((1, 7.7, 2.6), 2), ((1, 6.0, 2.2), 2), ((1, 6.9, 3.2), 2), ((1, 5.6, 2.8), 2), ((1, 7.7, 2.8), 2), ((1, 6.3, 2.7), 2), ((1, 6.7, 3.3), 2), ((1, 7.2, 3.2), 2), ((1, 6.2, 2.8), 2), ((1, 6.1, 3.0), 2), ((1, 6.4, 2.8), 2), ((1, 7.2, 3.0), 2), ((1, 7.4, 2.8), 2), ((1, 7.9, 3.8), 2), ((1, 6.4, 2.8), 2), ((1, 6.3, 2.8), 2), ((1, 6.1, 2.6), 2), ((1, 7.7, 3.0), 2), ((1, 6.3, 3.4), 2), ((1, 6.4, 3.1), 2), ((1, 6.0, 3.0), 2), ((1, 6.9, 3.1), 2), ((1, 6.7, 3.1), 2), ((1, 6.9, 3.1), 2), ((1, 5.8, 2.7), 2), ((1, 6.8, 3.2), 2), ((1, 6.7, 3.3), 2), ((1, 6.7, 3.0), 2), ((1, 6.3, 2.5), 2), ((1, 6.5, 3.0), 2), ((1, 6.2, 3.4), 2), ((1, 5.9, 3.0), 2)]

X = [(d[0], d[1], d[2]) for d,_ in data]
Y = [y for _, y in data]

#plt.plot(X[1], X[2], "g+")
#[xaxis.append(x),yaxis.append(y) for _,x,y in X]

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression(random_state=42, solver='sag', penalty='none', max_iter=10000, fit_intercept=False)
#log_reg = LogisticRegression(random_state=42, penalty='none', verbose=1, fit_intercept=False)
log_reg.fit(X, Y)
# Out:
# LogisticRegression(fit_intercept=False, max_iter=10000, penalty='none',
#                    random_state=42, solver='sag')

# %%
w=[round(c,2) for c in log_reg.coef_[0]]
print(w)

for x,y in zip(X, Y):
  print ("x,r,y=", x, y, sigmoid(F(w,x)), round(sigmoid(F(w,x)), 3), classify(sigmoid(F(w,x))))
# Out:
# [23.21, -9.61, 9.4]
# x,r,y= (1, 5.1, 3.5) 0 0.9991747511572614 0.999 1
# x,r,y= (1, 4.9, 3.0) 0 0.986887628402734 0.987 1
# x,r,y= (1, 4.7, 3.2) 0 0.9997034505556585 1.0 1
# x,r,y= (1, 4.6, 3.1) 0 0.9997096113706178 1.0 1
# x,r,y= (1, 5.0, 3.6) 0 0.9998766054240137 1.0 1
# x,r,y= (1, 5.4, 3.9) 0 0.9996565069062725 1.0 1
# x,r,y= (1, 4.6, 3.4) 0 0.9999826863839958 1.0 1
# x,r,y= (1, 5.0, 3.4) 0 0.9991918868239439 0.999 1
# x,r,y= (1, 4.4, 2.9) 0 0.9997215517929483 1.0 1
# x,r,y= (1, 4.9, 3.1) 0 0.9948366861663702 0.995 1
# x,r,y= (1, 5.4, 3.7) 0 0.9977532023102053 0.998 1
# x,r,y= (1, 4.8, 3.4) 0 0.9998816800694974 1.0 1
# x,r,y= (1, 4.8, 3.0) 0 0.9949434426104955 0.995 1
# x,r,y= (1, 4.3, 3.0) 0 0.9999583846561523 1.0 1
# x,r,y= (1, 5.8, 4.0) 0 0.993769198445403 0.994 1
# x,r,y= (1, 5.7, 4.4) 0 0.9999441619956889 1.0 1
# x,r,y= (1, 5.4, 3.9) 0 0.9996565069062725 1.0 1
# x,r,y= (1, 5.1, 3.5) 0 0.9991747511572614 0.999 1
# x,r,y= (1, 5.7, 3.8) 0 0.9845260135443054 0.985 1
# x,r,y= (1, 5.1, 3.8) 0 0.9999507720609687 1.0 1
# x,r,y= (1, 5.4, 3.4) 0 0.9635962293821564 0.964 1
# x,r,y= (1, 5.1, 3.7) 0 0.9998739870679387 1.0 1
# x,r,y= (1, 4.6, 3.6) 0 0.9999973580747412 1.0 1
# x,r,y= (1, 5.1, 3.3) 0 0.9946164008577664 0.995 1
# x,r,y= (1, 4.8, 3.4) 0 0.9998816800694974 1.0 1
# x,r,y= (1, 5.0, 3.0) 0 0.9664307767185177 0.966 1
# x,r,y= (1, 5.0, 3.4) 0 0.9991918868239439 0.999 1
# x,r,y= (1, 5.2, 3.5) 0 0.9978454144841861 0.998 1
# x,r,y= (1, 5.2, 3.4) 0 0.9945027779020004 0.995 1
# x,r,y= (1, 4.7, 3.2) 0 0.9997034505556585 1.0 1
# x,r,y= (1, 4.8, 3.1) 0 0.9980186627880491 0.998 1
# x,r,y= (1, 5.4, 3.4) 0 0.9635962293821564 0.964 1
# x,r,y= (1, 5.2, 4.1) 0 0.9999923285711673 1.0 1
# x,r,y= (1, 5.5, 4.2) 0 0.9999464585020937 1.0 1
# x,r,y= (1, 4.9, 3.1) 0 0.9948366861663702 0.995 1
# x,r,y= (1, 5.0, 3.2) 0 0.9947276877730513 0.995 1
# x,r,y= (1, 5.5, 3.5) 0 0.9628523655590605 0.963 1
# x,r,y= (1, 4.9, 3.6) 0 0.999952796721328 1.0 1
# x,r,y= (1, 4.4, 3.0) 0 0.9998912119206125 1.0 1
# x,r,y= (1, 5.1, 3.4) 0 0.9978900945321283 0.998 1
# x,r,y= (1, 5.0, 3.5) 0 0.9996841729729222 1.0 1
# x,r,y= (1, 4.5, 2.3) 0 0.8299114747646736 0.83 1
# x,r,y= (1, 4.4, 3.2) 0 0.9999833984849991 1.0 1
# x,r,y= (1, 5.0, 3.5) 0 0.9996841729729222 1.0 1
# x,r,y= (1, 5.1, 3.8) 0 0.9999507720609687 1.0 1
# x,r,y= (1, 4.8, 3.0) 0 0.9949434426104955 0.995 1
# x,r,y= (1, 5.1, 3.8) 0 0.9999507720609687 1.0 1
# x,r,y= (1, 4.6, 3.2) 0 0.9998865460420752 1.0 1
# x,r,y= (1, 5.3, 3.7) 0 0.9991393830029656 0.999 1
# x,r,y= (1, 5.0, 3.3) 0 0.9979338499599546 0.998 1
# x,r,y= (1, 7.0, 3.2) 1 8.483259938425951e-07 0.0 0
# x,r,y= (1, 6.4, 3.2) 1 0.0002707618790219578 0.0 0
# x,r,y= (1, 6.9, 3.1) 1 8.663291962926646e-07 0.0 0
# x,r,y= (1, 5.5, 2.3) 1 0.00032707301435101787 0.0 0
# x,r,y= (1, 6.5, 2.8) 1 2.412125106379251e-06 0.0 0
# x,r,y= (1, 5.7, 2.8) 1 0.005235727468133163 0.005 0
# x,r,y= (1, 6.3, 3.3) 1 0.0018093077841333472 0.002 0
# x,r,y= (1, 4.9, 2.4) 1 0.21098471553070494 0.211 0
# x,r,y= (1, 6.6, 2.9) 1 2.3619987674793244e-06 0.0 0
# x,r,y= (1, 5.2, 2.7) 1 0.20068798305620072 0.201 0
# x,r,y= (1, 5.0, 2.0) 1 0.0023759005664449966 0.002 0
# x,r,y= (1, 5.9, 3.0) 1 0.005021462203417294 0.005 0
# x,r,y= (1, 6.0, 2.2) 1 1.0465609588294177e-06 0.0 0
# x,r,y= (1, 6.1, 2.9) 1 0.0002883635910421317 0.0 0
# x,r,y= (1, 5.6, 2.9) 1 0.03402639377927093 0.034 0
# x,r,y= (1, 6.7, 3.1) 1 5.920995757020912e-06 0.0 0
# x,r,y= (1, 5.6, 3.0) 1 0.0827163092766914 0.083 0
# x,r,y= (1, 5.8, 2.7) 1 0.0007858173856542409 0.001 0
# x,r,y= (1, 6.2, 2.2) 1 1.531267000829215e-07 0.0 0
# x,r,y= (1, 5.6, 2.5) 1 0.0008194969898339767 0.001 0
# x,r,y= (1, 5.9, 3.2) 1 0.03201537337995886 0.032 0
# x,r,y= (1, 6.1, 2.8) 1 0.00011266264252855267 0.0 0
# x,r,y= (1, 6.3, 2.5) 1 9.826616449021912e-07 0.0 0
# x,r,y= (1, 6.1, 2.8) 1 0.00011266264252855267 0.0 0
# x,r,y= (1, 6.4, 2.9) 1 1.6143127458062152e-05 0.0 0
# x,r,y= (1, 6.6, 3.0) 1 6.046650674926058e-06 0.0 0
# x,r,y= (1, 6.8, 2.8) 1 1.3499877467930283e-07 0.0 0
# x,r,y= (1, 6.7, 3.0) 1 2.3129141009343136e-06 0.0 0
# x,r,y= (1, 6.0, 2.9) 1 0.000753520898581853 0.001 0
# x,r,y= (1, 5.7, 2.6) 1 0.0008024806600954282 0.001 0
# x,r,y= (1, 5.5, 2.4) 1 0.0008368738428550574 0.001 0
# x,r,y= (1, 5.5, 2.4) 1 0.0008368738428550574 0.001 0
# x,r,y= (1, 5.8, 2.7) 1 0.0007858173856542409 0.001 0
# x,r,y= (1, 6.0, 2.7) 1 0.00011505329986124977 0.0 0
# x,r,y= (1, 5.4, 3.0) 1 0.3813080293987083 0.381 0
# x,r,y= (1, 6.0, 3.4) 1 0.07656219735181252 0.077 0
# x,r,y= (1, 6.7, 3.1) 1 5.920995757020912e-06 0.0 0
# x,r,y= (1, 6.3, 2.3) 1 1.499445691802803e-07 0.0 0
# x,r,y= (1, 5.6, 3.0) 1 0.0827163092766914 0.083 0
# x,r,y= (1, 5.5, 2.5) 1 0.002139588238393798 0.002 0
# x,r,y= (1, 5.5, 2.6) 1 0.00545908524664718 0.005 0
# x,r,y= (1, 6.1, 3.0) 1 0.0007378735084110825 0.001 0
# x,r,y= (1, 5.8, 2.6) 1 0.00030710920519777106 0.0 0
# x,r,y= (1, 5.0, 2.3) 1 0.038419985501565425 0.038 0
# x,r,y= (1, 5.6, 2.7) 1 0.005346246310004271 0.005 0
# x,r,y= (1, 5.7, 3.0) 1 0.03334286694898177 0.033 0
# x,r,y= (1, 5.7, 2.9) 1 0.013294778100865663 0.013 0
# x,r,y= (1, 6.2, 2.9) 1 0.00011032165445264062 0.0 0
# x,r,y= (1, 5.1, 2.5) 1 0.09104017530394097 0.091 0
# x,r,y= (1, 5.7, 2.8) 1 0.005235727468133163 0.005 0
# x,r,y= (1, 6.3, 3.3) 2 0.0018093077841333472 0.002 0
# x,r,y= (1, 5.8, 2.7) 2 0.0007858173856542409 0.001 0
# x,r,y= (1, 7.1, 3.0) 2 4.951451146061474e-08 0.0 0
# x,r,y= (1, 6.3, 2.9) 2 4.220203130370741e-05 0.0 0
# x,r,y= (1, 6.5, 3.0) 2 1.5807661857407083e-05 0.0 0
# x,r,y= (1, 7.6, 3.0) 2 4.0545955013551005e-10 0.0 0
# x,r,y= (1, 4.9, 2.5) 2 0.40636810752947716 0.406 0
# x,r,y= (1, 7.3, 2.9) 2 2.8299692167329204e-09 0.0 0
# x,r,y= (1, 6.7, 2.5) 2 2.103664287382578e-08 0.0 0
# x,r,y= (1, 7.2, 3.6) 2 5.3308208243088045e-06 0.0 0
# x,r,y= (1, 6.5, 3.2) 2 0.00010358649519871365 0.0 0
# x,r,y= (1, 6.4, 2.7) 2 2.463315223845306e-06 0.0 0
# x,r,y= (1, 6.8, 3.0) 2 8.847144629657613e-07 0.0 0
# x,r,y= (1, 5.7, 2.5) 2 0.00031362464856413667 0.0 0
# x,r,y= (1, 5.8, 2.8) 2 0.002009214888267576 0.002 0
# x,r,y= (1, 6.4, 3.2) 2 0.0002707618790219578 0.0 0
# x,r,y= (1, 6.5, 3.0) 2 1.5807661857407083e-05 0.0 0
# x,r,y= (1, 7.7, 3.8) 2 2.860783003702747e-07 0.0 0
# x,r,y= (1, 7.7, 2.6) 2 3.611131347565332e-12 0.0 0
# x,r,y= (1, 6.0, 2.2) 2 1.0465609588294177e-06 0.0 0
# x,r,y= (1, 6.9, 3.2) 2 2.2177836474251274e-06 0.0 0
# x,r,y= (1, 5.6, 2.8) 2 0.01357309102284081 0.014 0
# x,r,y= (1, 7.7, 2.8) 2 2.3665566843805657e-11 0.0 0
# x,r,y= (1, 6.3, 2.7) 2 6.439842724141091e-06 0.0 0
# x,r,y= (1, 6.7, 3.3) 2 3.88019985845171e-05 0.0 0
# x,r,y= (1, 7.2, 3.2) 2 1.2412209432473155e-07 0.0 0
# x,r,y= (1, 6.2, 2.8) 2 4.309760639243668e-05 0.0 0
# x,r,y= (1, 6.1, 3.0) 2 0.0007378735084110825 0.001 0
# x,r,y= (1, 6.4, 2.8) 2 6.306016968236366e-06 0.0 0
# x,r,y= (1, 7.2, 3.0) 2 1.8939805491908852e-08 0.0 0
# x,r,y= (1, 7.4, 2.8) 2 4.2285152618572915e-10 0.0 0
# x,r,y= (1, 7.9, 3.8) 2 4.1857282456278695e-08 0.0 0
# x,r,y= (1, 6.4, 2.8) 2 6.306016968236366e-06 0.0 0
# x,r,y= (1, 6.3, 2.8) 2 1.6485712094723627e-05 0.0 0
# x,r,y= (1, 6.1, 2.6) 2 1.71928459640092e-05 0.0 0
# x,r,y= (1, 7.7, 3.0) 2 1.5509240735700707e-10 0.0 0
# x,r,y= (1, 6.3, 3.4) 2 0.0046187579254210595 0.005 0
# x,r,y= (1, 6.4, 3.1) 2 0.00010578458060062871 0.0 0
# x,r,y= (1, 6.0, 3.0) 2 0.0019267346633274891 0.002 0
# x,r,y= (1, 6.9, 3.1) 2 8.663291962926646e-07 0.0 0
# x,r,y= (1, 6.7, 3.1) 2 5.920995757020912e-06 0.0 0
# x,r,y= (1, 6.9, 3.1) 2 8.663291962926646e-07 0.0 0
# x,r,y= (1, 5.8, 2.7) 2 0.0007858173856542409 0.001 0
# x,r,y= (1, 6.8, 3.2) 2 5.79795204781586e-06 0.0 0
# x,r,y= (1, 6.7, 3.3) 2 3.88019985845171e-05 0.0 0
# x,r,y= (1, 6.7, 3.0) 2 2.3129141009343136e-06 0.0 0
# x,r,y= (1, 6.3, 2.5) 2 9.826616449021912e-07 0.0 0
# x,r,y= (1, 6.5, 3.0) 2 1.5807661857407083e-05 0.0 0
# x,r,y= (1, 6.2, 3.4) 2 0.011985497488607331 0.012 0
# x,r,y= (1, 5.9, 3.0) 2 0.005021462203417294 0.005 0

# %%
classify = lambda y: 1 if y>0.5 else 0
